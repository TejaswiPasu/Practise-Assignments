# %%
import pandas as pd

import numpy as np
 
# Creating a sample dataset

data = {'order_id': np.arange(1, 1001)}  # order_id from 1 to 1000

df = pd.DataFrame(data)
 
# Check the default data type

print(df['order_id'].dtype)  # This will show int64

print(f"Memory Usage: {df.memory_usage(deep=True)}")

# Convert order_id to int16 (smallest type that fits)

df['order_id'] = df['order_id'].astype(np.int16)
 
# Check the memory usage

print(f"Memory Usage: {df.memory_usage(deep=True)}")
 
#Memory Saving: The int16 takes only 2 bytes per value, whereas int64 takes 8 bytes.
 
# Creating a dataset with float values

data = {'sales_amount': np.random.random(1000000)}  # Random float values

df = pd.DataFrame(data)
 
# Check the default data type

print(df['sales_amount'].dtype)  # This will show float64
 
# Convert to float32 for memory optimization

df['sales_amount'] = df['sales_amount'].astype(np.float32)
 
# Check the memory usage

print(f"Memory Usage: {df.memory_usage(deep=True)}")
 
#float32 takes 4 bytes compared to 8 bytes for float64.
# Out:
# int32
# Memory Usage: Index        132
# order_id    4000
# dtype: int64
# Memory Usage: Index        132
# order_id    2000
# dtype: int64
# float64
# Memory Usage: Index               132
# sales_amount    4000000
# dtype: int64

# %%
import pandas as pd
 # Creating a dataset with repeated string values
data = {'city': ['New York', 'Los Angeles', 'Chicago', 'New York', 'Los Angeles'] * 100000}
df = pd.DataFrame(data)
 
# Check the memory usage with object type
print(df['city'].dtype)  # This will show object (i.e., string)
 
# Convert to category type
df['city'] = df['city'].astype('category')
 
# Check the memory usage after conversion
print(f"Memory Usage: {df.memory_usage(deep=True)}")
#1. Deletion
#Listwise Deletion: Remove rows with any missing values.
data_cleaned = df.dropna()
# Out:
# object
# Memory Usage: Index       132
# city     500305
# dtype: int64

# %%
df=pd.read_csv('data job posts.csv')
df.head()
# Out:
#                                              jobpost          date  \
# 0  AMERIA Investment Consulting Company\r\nJOB TI...   Jan 5, 2004
# 1  International Research & Exchanges Board (IREX...   Jan 7, 2004
# 2  Caucasus Environmental NGO Network (CENN)\r\nJ...   Jan 7, 2004
# 3  Manoff Group\r\nJOB TITLE:  BCC Specialist\r\n...   Jan 7, 2004
# 4  Yerevan Brandy Company\r\nJOB TITLE:  Software...  Jan 10, 2004
#
#                                                Title  \
# 0                            Chief Financial Officer
# 1  Full-time Community Connections Intern (paid i...
# 2                                Country Coordinator
# 3                                     BCC Specialist
# 4                                 Software Developer
#
#                                            Company AnnouncementCode Term  \
# 0             AMERIA Investment Consulting Company              NaN  NaN
# 1  International Research & Exchanges Board (IREX)              NaN  NaN
# 2        Caucasus Environmental NGO Network (CENN)              NaN  NaN
# 3                                     Manoff Group              NaN  NaN
# 4                           Yerevan Brandy Company              NaN  NaN
#
#   Eligibility Audience StartDate                               Duration  ...  \
# 0         NaN      NaN       NaN                                    NaN  ...
# 1         NaN      NaN       NaN                               3 months  ...
# 2         NaN      NaN       NaN  Renewable annual contract\r\nPOSITION  ...
# 3         NaN      NaN       NaN                                    NaN  ...
# 4         NaN      NaN       NaN                                    NaN  ...
#
#   Salary                                       ApplicationP OpeningDate  \
# 0    NaN  To apply for this position, please submit a\r\...         NaN
# 1    NaN  Please submit a cover letter and resume to:\r\...         NaN
# 2    NaN  Please send resume or CV toursula.kazarian@......         NaN
# 3    NaN  Please send cover letter and resume to Amy\r\n...         NaN
# 4    NaN  Successful candidates should submit\r\n- CV; \...         NaN
#
#                                         Deadline Notes  \
# 0                                26 January 2004   NaN
# 1                                12 January 2004   NaN
# 2  20 January 2004\r\nSTART DATE:  February 2004   NaN
# 3      23 January 2004\r\nSTART DATE:  Immediate   NaN
# 4                         20 January 2004, 18:00   NaN
#
#                                               AboutC Attach  Year Month     IT
# 0                                                NaN    NaN  2004     1  False
# 1  The International Research & Exchanges Board (...    NaN  2004     1  False
# 2  The Caucasus Environmental NGO Network is a\r\...    NaN  2004     1  False
# 3                                                NaN    NaN  2004     1  False
# 4                                                NaN    NaN  2004     1   True
#
# [5 rows x 24 columns]

# %%
print(df.isnull().sum())
# Out:
# jobpost                 0
# date                    0
# Title                  28
# Company                 7
# AnnouncementCode    17793
# Term                11325
# Eligibility         14071
# Audience            18361
# StartDate            9326
# Duration             8203
# Location               32
# JobDescription       3892
# JobRequirment        2522
# RequiredQual          484
# Salary               9379
# ApplicationP           60
# OpeningDate           706
# Deadline               65
# Notes               16790
# AboutC               6531
# Attach              17442
# Year                    0
# Month                   0
# IT                      0
# dtype: int64

# %%
df_cleaned = df.dropna()
df_cleaned
# Out:
# Empty DataFrame
# Columns: [jobpost, date, Title, Company, AnnouncementCode, Term, Eligibility, Audience, StartDate, Duration, Location, JobDescription, JobRequirment, RequiredQual, Salary, ApplicationP, OpeningDate, Deadline, Notes, AboutC, Attach, Year, Month, IT]
# Index: []
#
# [0 rows x 24 columns]

# %%
#  Handling Missing Values
print(df.isnull().sum())

# Fill missing values: mode for categorical, median for numerical
for col in df.select_dtypes(include=['object']).columns:
    df[col].fillna(df[col].mode()[0], inplace=True)  # Fill categorical with mode

for col in df.select_dtypes(include=['number']).columns:
    df[col].fillna(df[col].median(), inplace=True)  # Fill numeric with median

# Drop irrelevant columns if they contain excessive noise
df.drop(columns=["Attach", "Notes"], errors='ignore', inplace=True)
df
# Out:
#                                                  jobpost          date  \
# 0      AMERIA Investment Consulting Company\r\nJOB TI...   Jan 5, 2004
# 1      International Research & Exchanges Board (IREX...   Jan 7, 2004
# 2      Caucasus Environmental NGO Network (CENN)\r\nJ...   Jan 7, 2004
# 3      Manoff Group\r\nJOB TITLE:  BCC Specialist\r\n...   Jan 7, 2004
# 4      Yerevan Brandy Company\r\nJOB TITLE:  Software...  Jan 10, 2004
# ...                                                  ...           ...
# 18996  Technolinguistics NGO\r\n\r\n\r\nTITLE:  Senio...  Dec 28, 2015
# 18997  "Coca-Cola Hellenic Bottling Company Armenia" ...  Dec 30, 2015
# 18998  "Coca-Cola Hellenic Bottling Company Armenia" ...  Dec 30, 2015
# 18999  San Lazzaro   LLC\r\n\r\n\r\nTITLE:  Head of O...  Dec 30, 2015
# 19000  "Kamurj" UCO CJSC\r\n\r\n\r\nTITLE:  Lawyer in...  Dec 30, 2015
#
#                                                    Title  \
# 0                                Chief Financial Officer
# 1      Full-time Community Connections Intern (paid i...
# 2                                    Country Coordinator
# 3                                         BCC Specialist
# 4                                     Software Developer
# ...                                                  ...
# 18996                    Senior Creative UX/ UI Designer
# 18997                       Category Development Manager
# 18998                      Operational Marketing Manager
# 18999                    Head of Online Sales Department
# 19000                         Lawyer in Legal Department
#
#                                                  Company AnnouncementCode  \
# 0                   AMERIA Investment Consulting Company        IOS - 001
# 1        International Research & Exchanges Board (IREX)        IOS - 001
# 2              Caucasus Environmental NGO Network (CENN)        IOS - 001
# 3                                           Manoff Group        IOS - 001
# 4                                 Yerevan Brandy Company        IOS - 001
# ...                                                  ...              ...
# 18996                              Technolinguistics NGO        IOS - 001
# 18997  "Coca-Cola Hellenic Bottling Company Armenia" ...        IOS - 001
# 18998  "Coca-Cola Hellenic Bottling Company Armenia" ...        IOS - 001
# 18999                                  San Lazzaro   LLC        IOS - 001
# 19000                                  "Kamurj" UCO CJSC        IOS - 001
#
#             Term                    Eligibility                   Audience  \
# 0      Full time       All qualified candidates  All interested candidates
# 1      Full time       All qualified candidates  All interested candidates
# 2      Full time       All qualified candidates  All interested candidates
# 3      Full time       All qualified candidates  All interested candidates
# 4      Full time       All qualified candidates  All interested candidates
# ...          ...                            ...                        ...
# 18996  Full-time       All qualified candidates  All interested candidates
# 18997  Full-time  All interested professionals.  All interested candidates
# 18998  Full-time  All interested professionals.  All interested candidates
# 18999  Full time       All qualified candidates  All interested candidates
# 19000  Full-time       All qualified candidates  All interested candidates
#
#       StartDate                                        Duration  ...  \
# 0          ASAP                                       Long term  ...
# 1          ASAP                                        3 months  ...
# 2          ASAP           Renewable annual contract\r\nPOSITION  ...
# 3          ASAP                                       Long term  ...
# 4          ASAP                                       Long term  ...
# ...         ...                                             ...  ...
# 18996      ASAP                                       Long-term  ...
# 18997      ASAP  Long-term with a probation period of 3 months.  ...
# 18998      ASAP  Long-term with a probation period of 3 months.  ...
# 18999      ASAP                                       Long-term  ...
# 19000      ASAP                                      Indefinite  ...
#
#                                            JobRequirment  \
# 0      - Supervises financial management and administ...
# 1      - Participate in application design;\r\n- Prov...
# 2      - Working with the Country Director to provide...
# 3      - Identify gaps in knowledge and overseeing in...
# 4      - Rendering technical assistance to Database M...
# ...                                                  ...
# 18996  - Work closely with product and business teams...
# 18997  - Establish and manage Category Management dev...
# 18998  - Develop, establish and maintain marketing st...
# 18999  - Handle the project activites of the online s...
# 19000  - Properly provide internal legal services of ...
#
#                                             RequiredQual              Salary  \
# 0      To perform this job successfully, an\r\nindivi...         Competitive
# 1      - Bachelor's Degree; Master's is preferred;\r\...         Competitive
# 2      - Degree in environmentally related field, or ...         Competitive
# 3      - Advanced degree in public health, social sci...         Competitive
# 4      - University degree; economical background is ...         Competitive
# ...                                                  ...                 ...
# 18996  - At least 5 years of experience in Interface/...         Competitive
# 18997  - University degree, ideally business related;...         Competitive
# 18998  - Degree in Business, Marketing or a related f...         Competitive
# 18999  - At least 1 year of experience in online sale...  Highly competitive
# 19000  - Higher legal education; Master's degree is a...         Competitive
#
#                                             ApplicationP       OpeningDate  \
# 0      To apply for this position, please submit a\r\...      17 July 2009
# 1      Please submit a cover letter and resume to:\r\...      17 July 2009
# 2      Please send resume or CV toursula.kazarian@......      17 July 2009
# 3      Please send cover letter and resume to Amy\r\n...      17 July 2009
# 4      Successful candidates should submit\r\n- CV; \...      17 July 2009
# ...                                                  ...               ...
# 18996  To apply for this position, please send your\r...  29 December 2015
# 18997  All interested candidates are kindly requested...  30 December 2015
# 18998  All interested candidates are kindly requested...  30 December 2015
# 18999  Interested candidates can send their CVs to:\r...  30 December 2015
# 19000  All qualified applicants are encouraged to\r\n...  30 December 2015
#
#                                             Deadline  \
# 0                                    26 January 2004
# 1                                    12 January 2004
# 2      20 January 2004\r\nSTART DATE:  February 2004
# 3          23 January 2004\r\nSTART DATE:  Immediate
# 4                             20 January 2004, 18:00
# ...                                              ...
# 18996                                28 January 2016
# 18997                                20 January 2016
# 18998                                20 January 2016
# 18999                                29 January 2016
# 19000                                20 January 2016
#
#                                                   AboutC  Year Month     IT
# 0      Mentor Graphics Development Services CJSC is a...  2004     1  False
# 1      The International Research & Exchanges Board (...  2004     1  False
# 2      The Caucasus Environmental NGO Network is a\r\...  2004     1  False
# 3      Mentor Graphics Development Services CJSC is a...  2004     1  False
# 4      Mentor Graphics Development Services CJSC is a...  2004     1   True
# ...                                                  ...   ...   ...    ...
# 18996  As a company Technolinguistics has a mandate t...  2015    12  False
# 18997  Mentor Graphics Development Services CJSC is a...  2015    12  False
# 18998  Mentor Graphics Development Services CJSC is a...  2015    12  False
# 18999  San Lazzaro LLC works with several internation...  2015    12  False
# 19000  "Kamurj" UCO CJSC is providing micro and small...  2015    12  False
#
# [19001 rows x 22 columns]

# %%
pip install pandas numpy beautifulsoup4 nltk
# Out:
# Requirement already satisfied: pandas in c:\users\cvr\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: numpy in c:\users\cvr\anaconda3\lib\site-packages (1.24.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\cvr\anaconda3\lib\site-packages (4.12.2)
# Requirement already satisfied: nltk in c:\users\cvr\anaconda3\lib\site-packages (3.8.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\cvr\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cvr\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\cvr\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\cvr\anaconda3\lib\site-packages (from beautifulsoup4) (2.4)
# Requirement already satisfied: click in c:\users\cvr\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in c:\users\cvr\anaconda3\lib\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\cvr\anaconda3\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\cvr\anaconda3\lib\site-packages (from nltk) (4.65.0)
# Requirement already satisfied: six>=1.5 in c:\users\cvr\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: colorama in c:\users\cvr\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import re
from bs4 import BeautifulSoup
import nltk
from nltk.tokenize import word_tokenize
from datetime import datetime

# Download required NLTK data
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\cvr\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
# String Operations & Text Processing
#(a) Clean JobDescription & JobRequirement
def clean_text(text):
    if pd.isna(text):
        return ""
    text = BeautifulSoup(text, "html.parser").get_text()  # Remove HTML tags
    text = re.sub(r"[^a-zA-Z0-9\s]", "", text)  # Remove special characters
    text = re.sub(r"\s+", " ", text).strip()  # Remove extra whitespace
    text = text.lower()  # Convert to lowercase
    return text

df["JobD"] = df["JobDescription"].apply(clean_text)
df["JobRequirment"] = df["JobRequirment"].apply(clean_text)
# Out:
# C:\Users\cvr\AppData\Local\Temp\ipykernel_1380\2001038718.py:4: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text = BeautifulSoup(text, "html.parser").get_text()  # Remove HTML tags

# %%
# Extract Key Skills from JobDescription
skills = ["python", "java", "sql", "machine learning", "data science", "excel", "aws", "cloud"]

def extract_skills(text):
    tokens = word_tokenize(text)
    found_skills = [skill for skill in skills if skill in tokens]
    return ", ".join(found_skills)

df["KeySkills"] = df["JobDescription"].apply(extract_skills)

# %%
# Normalize Title & Standardize Term
title_mapping = {
    "software eng.": "Software Engineer",
    "dev": "Developer",
    "full stack dev": "Full Stack Developer"
}

df["Title"] = df["Title"].str.lower().replace(title_mapping)

df["Term"] = df["Term"].str.replace(r"ft|full time", "Full-time", regex=True)
df["Term"] = df["Term"].str.replace(r"pt|part time", "Part-time", regex=True)

# %%
#Date operations
# Convert date columns to datetime
date_cols = ["date", "StartDate", "OpeningDate", "Deadline"]
for col in date_cols:
    df[col] = pd.to_datetime(df[col], errors="coerce")

# Calculate Days Left to Apply
df["DaysLeftToApply"] = (df["Deadline"] - df["OpeningDate"]).dt.days

# Calculate Job Start Delay
df["JobStartDelay"] = (df["StartDate"] - df["OpeningDate"]).dt.days

# Extract Year and Month
df["OpeningYear"] = df["OpeningDate"].dt.year
df["OpeningMonth"] = df["OpeningDate"].dt.month

# %%
# Splitting & Extracting Data
#(a) Split Location into City & Country
df[["City", "Country"]] = df["Location"].str.split(",", expand=True, n=1)

# %%
#Extract Numeric Salary Range
def extract_salary(salary_text):
    if pd.isna(salary_text):
        return pd.Series([None, None])
    
    numbers = re.findall(r"\d+", salary_text)  # Extract numbers
    if len(numbers) >= 2:
        return pd.Series([int(numbers[0]) * 1000, int(numbers[1]) * 1000])  # Convert "50K" to "50000"
    elif len(numbers) == 1:
        return pd.Series([int(numbers[0]) * 1000, None])
    return pd.Series([None, None])

df[["MinSalary", "MaxSalary"]] = df["Salary"].apply(extract_salary)

# %%
# Filtering & Categorization
#(a) Identify IT-Related Jobs
df["IsITJob"] = df["IT"].apply(lambda x: 1 if str(x).lower() in ["yes", "it", "tech"] else 0)

# %%
# Categorize Eligibility & Audience into Structured Education Level
def categorize_education(education):
    education = str(education).lower()
    if "phd" in education:
        return "PhD"
    elif "master" in education or "mba" in education:
        return "Master's"
    elif "bachelor" in education or "bsc" in education:
        return "Bachelor's"
    elif "diploma" in education:
        return "Diploma"
    else:
        return "Other"

df["EducationLevel"] = df["Eligibility"].apply(categorize_education)

# %%
df
# Out:
#                                                  jobpost       date  \
# 0      AMERIA Investment Consulting Company\r\nJOB TI... 2004-01-05
# 1      International Research & Exchanges Board (IREX... 2004-01-07
# 2      Caucasus Environmental NGO Network (CENN)\r\nJ... 2004-01-07
# 3      Manoff Group\r\nJOB TITLE:  BCC Specialist\r\n... 2004-01-07
# 4      Yerevan Brandy Company\r\nJOB TITLE:  Software... 2004-01-10
# ...                                                  ...        ...
# 18996  Technolinguistics NGO\r\n\r\n\r\nTITLE:  Senio... 2015-12-28
# 18997  "Coca-Cola Hellenic Bottling Company Armenia" ... 2015-12-30
# 18998  "Coca-Cola Hellenic Bottling Company Armenia" ... 2015-12-30
# 18999  San Lazzaro   LLC\r\n\r\n\r\nTITLE:  Head of O... 2015-12-30
# 19000  "Kamurj" UCO CJSC\r\n\r\n\r\nTITLE:  Lawyer in... 2015-12-30
#
#                                                    Title  \
# 0                                chief financial officer
# 1      full-time community connections intern (paid i...
# 2                                    country coordinator
# 3                                         bcc specialist
# 4                                     software developer
# ...                                                  ...
# 18996                    senior creative ux/ ui designer
# 18997                       category development manager
# 18998                      operational marketing manager
# 18999                    head of online sales department
# 19000                         lawyer in legal department
#
#                                                  Company AnnouncementCode  \
# 0                   AMERIA Investment Consulting Company        IOS - 001
# 1        International Research & Exchanges Board (IREX)        IOS - 001
# 2              Caucasus Environmental NGO Network (CENN)        IOS - 001
# 3                                           Manoff Group        IOS - 001
# 4                                 Yerevan Brandy Company        IOS - 001
# ...                                                  ...              ...
# 18996                              Technolinguistics NGO        IOS - 001
# 18997  "Coca-Cola Hellenic Bottling Company Armenia" ...        IOS - 001
# 18998  "Coca-Cola Hellenic Bottling Company Armenia" ...        IOS - 001
# 18999                                  San Lazzaro   LLC        IOS - 001
# 19000                                  "Kamurj" UCO CJSC        IOS - 001
#
#             Term                    Eligibility                   Audience  \
# 0      Full time       All qualified candidates  All interested candidates
# 1      Full time       All qualified candidates  All interested candidates
# 2      Full time       All qualified candidates  All interested candidates
# 3      Full time       All qualified candidates  All interested candidates
# 4      Full time       All qualified candidates  All interested candidates
# ...          ...                            ...                        ...
# 18996  Full-time       All qualified candidates  All interested candidates
# 18997  Full-time  All interested professionals.  All interested candidates
# 18998  Full-time  All interested professionals.  All interested candidates
# 18999  Full time       All qualified candidates  All interested candidates
# 19000  Full-time       All qualified candidates  All interested candidates
#
#       StartDate                                        Duration  ...  \
# 0           NaT                                       Long term  ...
# 1           NaT                                        3 months  ...
# 2           NaT           Renewable annual contract\r\nPOSITION  ...
# 3           NaT                                       Long term  ...
# 4           NaT                                       Long term  ...
# ...         ...                                             ...  ...
# 18996       NaT                                       Long-term  ...
# 18997       NaT  Long-term with a probation period of 3 months.  ...
# 18998       NaT  Long-term with a probation period of 3 months.  ...
# 18999       NaT                                       Long-term  ...
# 19000       NaT                                      Indefinite  ...
#
#       DaysLeftToApply JobStartDelay OpeningYear OpeningMonth  \
# 0             -1999.0           NaN      2009.0          7.0
# 1             -2013.0           NaN      2009.0          7.0
# 2                 NaN           NaN      2009.0          7.0
# 3                 NaN           NaN      2009.0          7.0
# 4                 NaN           NaN      2009.0          7.0
# ...               ...           ...         ...          ...
# 18996            30.0           NaN      2015.0         12.0
# 18997            21.0           NaN      2015.0         12.0
# 18998            21.0           NaN      2015.0         12.0
# 18999            30.0           NaN      2015.0         12.0
# 19000            21.0           NaN      2015.0         12.0
#
#                                     City  \
# 0                                Yerevan
# 1      IREX Armenia Main Office; Yerevan
# 2                                Yerevan
# 3                                 Manila
# 4                                Yerevan
# ...                                  ...
# 18996                            Yerevan
# 18997                            Yerevan
# 18998                            Yerevan
# 18999                            Yerevan
# 19000                            Yerevan
#
#                                                  Country MinSalary MaxSalary  \
# 0                                                Armenia       NaN       NaN
# 1       Armenia \r\nDESCRIPTION:   IREX currently see...       NaN       NaN
# 2                                                Armenia       NaN       NaN
# 3                                            Philippines       NaN       NaN
# 4                                                Armenia       NaN       NaN
# ...                                                  ...       ...       ...
# 18996                                            Armenia       NaN       NaN
# 18997                                            Armenia       NaN       NaN
# 18998                                            Armenia       NaN       NaN
# 18999                                            Armenia       NaN       NaN
# 19000                                            Armenia       NaN       NaN
#
#       IsITJob  EducationLevel
# 0           0           Other
# 1           0           Other
# 2           0           Other
# 3           0           Other
# 4           0           Other
# ...       ...             ...
# 18996       0           Other
# 18997       0           Other
# 18998       0           Other
# 18999       0           Other
# 19000       0           Other
#
# [19001 rows x 34 columns]

# %%
df.to_csv("cleaned_job_postings.csv", index=False)
